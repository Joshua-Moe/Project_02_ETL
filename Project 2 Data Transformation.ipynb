# %%
import pandas as pd

# %%
#read congressional csv file
congressional_df = pd.read_csv("1981st_Congressional_dataset.csv")
congressional_df.head()
# Out:
#   Chamber    State First_Name Middle_Name  Last_Name Suffix Party  \
# 0  Senate  Alabama     Howell         NaN     Heflin    NaN     D
# 1  Senate  Alabama   Jeremiah         NaN     Denton    NaN     R
# 2  Senate   Alaska        Ted         NaN    Stevens    NaN     R
# 3  Senate   Alaska      Frank         NaN  Murkowski    NaN     R
# 4  Senate  Arizona     Dennis         NaN  DeConcini    NaN     D
#
#    Congressional_Year
# 0                1981
# 1                1981
# 2                1981
# 3                1981
# 4                1981

# %%
#read State Birds csv file
State_Birds_df = pd.read_csv("State_Birds.csv")
State_Birds_df.head()
# Out:
#             State                                 State Bird
# 0         Alabama            Yellowhammer (northern flicker)
# 1          Alaska                           Willow ptarmigan
# 2  American Samoa  None(See List of birds of American Samoa)
# 3         Arizona                                Cactus wren
# 4        Arkansas                       Northern mockingbird

# %%
#merge csv files into one dataframe
merged_df = pd.merge(congressional_df, State_Birds_df, on="State")

merged_df.head()
# Out:
#   Chamber    State First_Name Middle_Name  Last_Name Suffix Party  \
# 0  Senate  Alabama     Howell         NaN     Heflin    NaN     D
# 1  Senate  Alabama   Jeremiah         NaN     Denton    NaN     R
# 2   House  Alabama       Jack         NaN    Edwards    NaN     R
# 3   House  Alabama    William       Louis  Dickinson    NaN     R
# 4   House  Alabama       Bill         NaN    Nichols    NaN     D
#
#    Congressional_Year                       State Bird
# 0                1981  Yellowhammer (northern flicker)
# 1                1981  Yellowhammer (northern flicker)
# 2                1981  Yellowhammer (northern flicker)
# 3                1981  Yellowhammer (northern flicker)
# 4                1981  Yellowhammer (northern flicker)

# %%
#filtered rows for just Senate
senators = merged_df.loc[merged_df["Chamber"]=="Senate"]
senators.head()
# Out:
#    Chamber    State First_Name Middle_Name  Last_Name Suffix Party  \
# 0   Senate  Alabama     Howell         NaN     Heflin    NaN     D
# 1   Senate  Alabama   Jeremiah         NaN     Denton    NaN     R
# 9   Senate   Alaska        Ted         NaN    Stevens    NaN     R
# 10  Senate   Alaska      Frank         NaN  Murkowski    NaN     R
# 12  Senate  Arizona     Dennis         NaN  DeConcini    NaN     D
#
#     Congressional_Year                       State Bird
# 0                 1981  Yellowhammer (northern flicker)
# 1                 1981  Yellowhammer (northern flicker)
# 9                 1981                 Willow ptarmigan
# 10                1981                 Willow ptarmigan
# 12                1981                      Cactus wren

# %%
#cleaned data by dropping columns
senators = senators.drop(columns=["Middle_Name","Suffix"], axis=1)

senators.head()
# Out:
#    Chamber    State First_Name  Last_Name Party  Congressional_Year  \
# 0   Senate  Alabama     Howell     Heflin     D                1981
# 1   Senate  Alabama   Jeremiah     Denton     R                1981
# 9   Senate   Alaska        Ted    Stevens     R                1981
# 10  Senate   Alaska      Frank  Murkowski     R                1981
# 12  Senate  Arizona     Dennis  DeConcini     D                1981
#
#                          State Bird
# 0   Yellowhammer (northern flicker)
# 1   Yellowhammer (northern flicker)
# 9                  Willow ptarmigan
# 10                 Willow ptarmigan
# 12                      Cactus wren

# %%
#created csv file
senators.to_csv("senators.csv", index=False)

# %%
from pprint import pprint

# %%
# convert the dataframe to a list of dictionaries to be prepared to import into MongoDB 
state_senators_birds = senators.to_dict('records') 
pprint(state_senators_birds)
# Out:
# [{'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Howell',
#   'Last_Name': 'Heflin',
#   'Party': 'D',
#   'State': 'Alabama',
#   'State Bird': 'Yellowhammer (northern flicker)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Jeremiah',
#   'Last_Name': 'Denton',
#   'Party': 'R',
#   'State': 'Alabama',
#   'State Bird': 'Yellowhammer (northern flicker)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Ted',
#   'Last_Name': 'Stevens',
#   'Party': 'R',
#   'State': 'Alaska',
#   'State Bird': 'Willow ptarmigan'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Frank',
#   'Last_Name': 'Murkowski',
#   'Party': 'R',
#   'State': 'Alaska',
#   'State Bird': 'Willow ptarmigan'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Dennis',
#   'Last_Name': 'DeConcini',
#   'Party': 'D',
#   'State': 'Arizona',
#   'State Bird': 'Cactus wren'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Barry',
#   'Last_Name': 'Goldwater',
#   'Party': 'R',
#   'State': 'Arizona',
#   'State Bird': 'Cactus wren'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'David',
#   'Last_Name': 'Pryor',
#   'Party': 'D',
#   'State': 'Arkansas',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Dale',
#   'Last_Name': 'Bumpers',
#   'Party': 'D',
#   'State': 'Arkansas',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'S.',
#   'Last_Name': 'Hayakawa',
#   'Party': 'R',
#   'State': 'California',
#   'State Bird': 'California quail'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Alan',
#   'Last_Name': 'Cranston',
#   'Party': 'D',
#   'State': 'California',
#   'State Bird': 'California quail'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'William',
#   'Last_Name': 'Armstrong',
#   'Party': 'R',
#   'State': 'Colorado',
#   'State Bird': 'Lark bunting'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Gary',
#   'Last_Name': 'Hart',
#   'Party': 'D',
#   'State': 'Colorado',
#   'State Bird': 'Lark bunting'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Lowell',
#   'Last_Name': 'Weicker',
#   'Party': 'R',
#   'State': 'Connecticut',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Chris',
#   'Last_Name': 'Dodd',
#   'Party': 'D',
#   'State': 'Connecticut',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'William',
#   'Last_Name': 'Roth',
#   'Party': 'R',
#   'State': 'Delaware',
#   'State Bird': 'Delaware Blue Hen'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Joe',
#   'Last_Name': 'Biden',
#   'Party': 'D',
#   'State': 'Delaware',
#   'State Bird': 'Delaware Blue Hen'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Lawton',
#   'Last_Name': 'Chiles',
#   'Party': 'D',
#   'State': 'Florida',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Paula',
#   'Last_Name': 'Hawkins',
#   'Party': 'R',
#   'State': 'Florida',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Sam',
#   'Last_Name': 'Nunn',
#   'Party': 'D',
#   'State': 'Georgia',
#   'State Bird': 'Brown thrasher'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Mack',
#   'Last_Name': 'Mattingly',
#   'Party': 'R',
#   'State': 'Georgia',
#   'State Bird': 'Brown thrasher'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Spark',
#   'Last_Name': 'Matsunaga',
#   'Party': 'D',
#   'State': 'Hawaii',
#   'State Bird': 'Hawaiian goose (nēnē)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Daniel',
#   'Last_Name': 'Inouye',
#   'Party': 'D',
#   'State': 'Hawaii',
#   'State Bird': 'Hawaiian goose (nēnē)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'James',
#   'Last_Name': 'McClure',
#   'Party': 'R',
#   'State': 'Idaho',
#   'State Bird': 'Mountain bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Steve',
#   'Last_Name': 'Symms',
#   'Party': 'R',
#   'State': 'Idaho',
#   'State Bird': 'Mountain bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Charles',
#   'Last_Name': 'Percy',
#   'Party': 'R',
#   'State': 'Illinois',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Alan',
#   'Last_Name': 'Dixon',
#   'Party': 'D',
#   'State': 'Illinois',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Richard',
#   'Last_Name': 'Lugar',
#   'Party': 'R',
#   'State': 'Indiana',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Dan',
#   'Last_Name': 'Quayle',
#   'Party': 'R',
#   'State': 'Indiana',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Roger',
#   'Last_Name': 'Jepsen',
#   'Party': 'R',
#   'State': 'Iowa',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Chuck',
#   'Last_Name': 'Grassley',
#   'Party': 'R',
#   'State': 'Iowa',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Nancy',
#   'Last_Name': 'Kassebaum',
#   'Party': 'R',
#   'State': 'Kansas',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Bob',
#   'Last_Name': 'Dole',
#   'Party': 'R',
#   'State': 'Kansas',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Walter',
#   'Last_Name': 'Huddleston',
#   'Party': 'D',
#   'State': 'Kentucky',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Wendell',
#   'Last_Name': 'Ford',
#   'Party': 'D',
#   'State': 'Kentucky',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'J.',
#   'Last_Name': 'Johnston',
#   'Party': 'D',
#   'State': 'Louisiana',
#   'State Bird': 'Brown pelican'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Russell',
#   'Last_Name': 'Long',
#   'Party': 'D',
#   'State': 'Louisiana',
#   'State Bird': 'Brown pelican'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'George',
#   'Last_Name': 'Mitchell',
#   'Party': 'D',
#   'State': 'Maine',
#   'State Bird': 'Chickadee'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'William',
#   'Last_Name': 'Cohen',
#   'Party': 'R',
#   'State': 'Maine',
#   'State Bird': 'Chickadee'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Paul',
#   'Last_Name': 'Sarbanes',
#   'Party': 'D',
#   'State': 'Maryland',
#   'State Bird': 'Baltimore oriole'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Charles',
#   'Last_Name': 'Mathias',
#   'Party': 'R',
#   'State': 'Maryland',
#   'State Bird': 'Baltimore oriole'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Ted',
#   'Last_Name': 'Kennedy',
#   'Party': 'D',
#   'State': 'Massachusetts',
#   'State Bird': 'Black-capped chickadee'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Paul',
#   'Last_Name': 'Tsongas',
#   'Party': 'D',
#   'State': 'Massachusetts',
#   'State Bird': 'Black-capped chickadee'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Donald',
#   'Last_Name': 'Riegle',
#   'Party': 'D',
#   'State': 'Michigan',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Carl',
#   'Last_Name': 'Levin',
#   'Party': 'D',
#   'State': 'Michigan',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'David',
#   'Last_Name': 'Durenberger',
#   'Party': 'R',
#   'State': 'Minnesota',
#   'State Bird': 'Common loon'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Rudy',
#   'Last_Name': 'Boschwitz',
#   'Party': 'R',
#   'State': 'Minnesota',
#   'State Bird': 'Common loon'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Stennis',
#   'Party': 'D',
#   'State': 'Mississippi',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Thad',
#   'Last_Name': 'Cochran',
#   'Party': 'R',
#   'State': 'Mississippi',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Danforth',
#   'Party': 'R',
#   'State': 'Missouri',
#   'State Bird': 'Eastern bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Thomas',
#   'Last_Name': 'Eagleton',
#   'Party': 'D',
#   'State': 'Missouri',
#   'State Bird': 'Eastern bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Melcher',
#   'Party': 'D',
#   'State': 'Montana',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Max',
#   'Last_Name': 'Baucus',
#   'Party': 'D',
#   'State': 'Montana',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Edward',
#   'Last_Name': 'Zorinsky',
#   'Party': 'D',
#   'State': 'Nebraska',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'J.',
#   'Last_Name': 'Exon',
#   'Party': 'D',
#   'State': 'Nebraska',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Howard',
#   'Last_Name': 'Cannon',
#   'Party': 'D',
#   'State': 'Nevada',
#   'State Bird': 'Mountain bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Paul',
#   'Last_Name': 'Laxalt',
#   'Party': 'R',
#   'State': 'Nevada',
#   'State Bird': 'Mountain bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Gordon',
#   'Last_Name': 'Humphrey',
#   'Party': 'R',
#   'State': 'New Hampshire',
#   'State Bird': 'Purple finch'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Warren',
#   'Last_Name': 'Rudman',
#   'Party': 'R',
#   'State': 'New Hampshire',
#   'State Bird': 'Purple finch'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Harrison',
#   'Last_Name': 'Williams',
#   'Party': 'D',
#   'State': 'New Jersey',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Nicholas',
#   'Last_Name': 'Brady',
#   'Party': 'R',
#   'State': 'New Jersey',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Frank',
#   'Last_Name': 'Lautenberg',
#   'Party': 'D',
#   'State': 'New Jersey',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Bill',
#   'Last_Name': 'Bradley',
#   'Party': 'D',
#   'State': 'New Jersey',
#   'State Bird': 'Eastern goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Harrison',
#   'Last_Name': 'Schmitt',
#   'Party': 'R',
#   'State': 'New Mexico',
#   'State Bird': 'Greater roadrunner'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Pete',
#   'Last_Name': 'Domenici',
#   'Party': 'R',
#   'State': 'New Mexico',
#   'State Bird': 'Greater roadrunner'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Daniel',
#   'Last_Name': 'Moynihan',
#   'Party': 'D',
#   'State': 'New York',
#   'State Bird': 'Eastern bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Al',
#   'Last_Name': "D'Amato",
#   'Party': 'R',
#   'State': 'New York',
#   'State Bird': 'Eastern bluebird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Jesse',
#   'Last_Name': 'Helms',
#   'Party': 'R',
#   'State': 'North Carolina',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'East',
#   'Party': 'R',
#   'State': 'North Carolina',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Quentin',
#   'Last_Name': 'Burdick',
#   'Party': 'D-NPL',
#   'State': 'North Dakota',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Mark',
#   'Last_Name': 'Andrews',
#   'Party': 'R',
#   'State': 'North Dakota',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Howard',
#   'Last_Name': 'Metzenbaum',
#   'Party': 'D',
#   'State': 'Ohio',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Glenn',
#   'Party': 'D',
#   'State': 'Ohio',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'David',
#   'Last_Name': 'Boren',
#   'Party': 'D',
#   'State': 'Oklahoma',
#   'State Bird': 'Scissor-tailed flycatcher'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Don',
#   'Last_Name': 'Nickles',
#   'Party': 'R',
#   'State': 'Oklahoma',
#   'State Bird': 'Scissor-tailed flycatcher'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Mark',
#   'Last_Name': 'Hatfield',
#   'Party': 'R',
#   'State': 'Oregon',
#   'State Bird': 'Western meadowlark(state songbird)[a]'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Bob',
#   'Last_Name': 'Packwood',
#   'Party': 'R',
#   'State': 'Oregon',
#   'State Bird': 'Western meadowlark(state songbird)[a]'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Heinz',
#   'Party': 'R',
#   'State': 'Pennsylvania',
#   'State Bird': 'Ruffed grouse[b]'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Arlen',
#   'Last_Name': 'Specter',
#   'Party': 'R',
#   'State': 'Pennsylvania',
#   'State Bird': 'Ruffed grouse[b]'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Chafee',
#   'Party': 'R',
#   'State': 'Rhode Island',
#   'State Bird': 'Rhode Island Red'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Claiborne',
#   'Last_Name': 'Pell',
#   'Party': 'D',
#   'State': 'Rhode Island',
#   'State Bird': 'Rhode Island Red'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Strom',
#   'Last_Name': 'Thurmond',
#   'Party': 'R',
#   'State': 'South Carolina',
#   'State Bird': 'Carolina wren'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Fritz',
#   'Last_Name': 'Hollings',
#   'Party': 'D',
#   'State': 'South Carolina',
#   'State Bird': 'Carolina wren'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Larry',
#   'Last_Name': 'Pressler',
#   'Party': 'R',
#   'State': 'South Dakota',
#   'State Bird': 'Ring-necked pheasant'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'James',
#   'Last_Name': 'Abdnor',
#   'Party': 'R',
#   'State': 'South Dakota',
#   'State Bird': 'Ring-necked pheasant'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Jim',
#   'Last_Name': 'Sasser',
#   'Party': 'D',
#   'State': 'Tennessee',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Howard',
#   'Last_Name': 'Baker',
#   'Party': 'R',
#   'State': 'Tennessee',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Lloyd',
#   'Last_Name': 'Bentsen',
#   'Party': 'D',
#   'State': 'Texas',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Tower',
#   'Party': 'R',
#   'State': 'Texas',
#   'State Bird': 'Northern mockingbird'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Orrin',
#   'Last_Name': 'Hatch',
#   'Party': 'R',
#   'State': 'Utah',
#   'State Bird': 'California gull'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Jake',
#   'Last_Name': 'Garn',
#   'Party': 'R',
#   'State': 'Utah',
#   'State Bird': 'California gull'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Robert',
#   'Last_Name': 'Stafford',
#   'Party': 'R',
#   'State': 'Vermont',
#   'State Bird': 'Hermit thrush'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Patrick',
#   'Last_Name': 'Leahy',
#   'Party': 'D',
#   'State': 'Vermont',
#   'State Bird': 'Hermit thrush'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Harry',
#   'Last_Name': 'Byrd',
#   'Party': 'I',
#   'State': 'Virginia',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'John',
#   'Last_Name': 'Warner',
#   'Party': 'R',
#   'State': 'Virginia',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Henry',
#   'Last_Name': 'Jackson',
#   'Party': 'D',
#   'State': 'Washington',
#   'State Bird': 'Willow goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Slade',
#   'Last_Name': 'Gorton',
#   'Party': 'R',
#   'State': 'Washington',
#   'State Bird': 'Willow goldfinch (American goldfinch)'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Robert',
#   'Last_Name': 'Byrd',
#   'Party': 'D',
#   'State': 'West Virginia',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Jennings',
#   'Last_Name': 'Randolph',
#   'Party': 'D',
#   'State': 'West Virginia',
#   'State Bird': 'Northern cardinal'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'William',
#   'Last_Name': 'Proxmire',
#   'Party': 'D',
#   'State': 'Wisconsin',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Bob',
#   'Last_Name': 'Kasten',
#   'Party': 'R',
#   'State': 'Wisconsin',
#   'State Bird': 'American robin'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Malcolm',
#   'Last_Name': 'Wallop',
#   'Party': 'R',
#   'State': 'Wyoming',
#   'State Bird': 'Western meadowlark'},
#  {'Chamber': 'Senate',
#   'Congressional_Year': 1981,
#   'First_Name': 'Alan',
#   'Last_Name': 'Simpson',
#   'Party': 'R',
#   'State': 'Wyoming',
#   'State Bird': 'Western meadowlark'}]

# %%
from pymongo import MongoClient

# %%
# create an instance of MongoClient 
mongo = MongoClient(port=27017)

# %%
# make a reference to the new database named Congressional_and_State_Bird_Relation with the collection named  
db = mongo.Congressional_and_State_Bird_Relation
senate = db.senate

# %%
# use insert_many() to insert data from the extracted DataFrame info 
senate.insert_many(state_senators_birds)
# Out:
# InsertManyResult([ObjectId('6679f82988016b7e5382624b'), ObjectId('6679f82988016b7e5382624c'), ObjectId('6679f82988016b7e5382624d'), ObjectId('6679f82988016b7e5382624e'), ObjectId('6679f82988016b7e5382624f'), ObjectId('6679f82988016b7e53826250'), ObjectId('6679f82988016b7e53826251'), ObjectId('6679f82988016b7e53826252'), ObjectId('6679f82988016b7e53826253'), ObjectId('6679f82988016b7e53826254'), ObjectId('6679f82988016b7e53826255'), ObjectId('6679f82988016b7e53826256'), ObjectId('6679f82988016b7e53826257'), ObjectId('6679f82988016b7e53826258'), ObjectId('6679f82988016b7e53826259'), ObjectId('6679f82988016b7e5382625a'), ObjectId('6679f82988016b7e5382625b'), ObjectId('6679f82988016b7e5382625c'), ObjectId('6679f82988016b7e5382625d'), ObjectId('6679f82988016b7e5382625e'), ObjectId('6679f82988016b7e5382625f'), ObjectId('6679f82988016b7e53826260'), ObjectId('6679f82988016b7e53826261'), ObjectId('6679f82988016b7e53826262'), ObjectId('6679f82988016b7e53826263'), ObjectId('6679f82988016b7e53826264'), ObjectId('6679f82988016b7e53826265'), ObjectId('6679f82988016b7e53826266'), ObjectId('6679f82988016b7e53826267'), ObjectId('6679f82988016b7e53826268'), ObjectId('6679f82988016b7e53826269'), ObjectId('6679f82988016b7e5382626a'), ObjectId('6679f82988016b7e5382626b'), ObjectId('6679f82988016b7e5382626c'), ObjectId('6679f82988016b7e5382626d'), ObjectId('6679f82988016b7e5382626e'), ObjectId('6679f82988016b7e5382626f'), ObjectId('6679f82988016b7e53826270'), ObjectId('6679f82988016b7e53826271'), ObjectId('6679f82988016b7e53826272'), ObjectId('6679f82988016b7e53826273'), ObjectId('6679f82988016b7e53826274'), ObjectId('6679f82988016b7e53826275'), ObjectId('6679f82988016b7e53826276'), ObjectId('6679f82988016b7e53826277'), ObjectId('6679f82988016b7e53826278'), ObjectId('6679f82988016b7e53826279'), ObjectId('6679f82988016b7e5382627a'), ObjectId('6679f82988016b7e5382627b'), ObjectId('6679f82988016b7e5382627c'), ObjectId('6679f82988016b7e5382627d'), ObjectId('6679f82988016b7e5382627e'), ObjectId('6679f82988016b7e5382627f'), ObjectId('6679f82988016b7e53826280'), ObjectId('6679f82988016b7e53826281'), ObjectId('6679f82988016b7e53826282'), ObjectId('6679f82988016b7e53826283'), ObjectId('6679f82988016b7e53826284'), ObjectId('6679f82988016b7e53826285'), ObjectId('6679f82988016b7e53826286'), ObjectId('6679f82988016b7e53826287'), ObjectId('6679f82988016b7e53826288'), ObjectId('6679f82988016b7e53826289'), ObjectId('6679f82988016b7e5382628a'), ObjectId('6679f82988016b7e5382628b'), ObjectId('6679f82988016b7e5382628c'), ObjectId('6679f82988016b7e5382628d'), ObjectId('6679f82988016b7e5382628e'), ObjectId('6679f82988016b7e5382628f'), ObjectId('6679f82988016b7e53826290'), ObjectId('6679f82988016b7e53826291'), ObjectId('6679f82988016b7e53826292'), ObjectId('6679f82988016b7e53826293'), ObjectId('6679f82988016b7e53826294'), ObjectId('6679f82988016b7e53826295'), ObjectId('6679f82988016b7e53826296'), ObjectId('6679f82988016b7e53826297'), ObjectId('6679f82988016b7e53826298'), ObjectId('6679f82988016b7e53826299'), ObjectId('6679f82988016b7e5382629a'), ObjectId('6679f82988016b7e5382629b'), ObjectId('6679f82988016b7e5382629c'), ObjectId('6679f82988016b7e5382629d'), ObjectId('6679f82988016b7e5382629e'), ObjectId('6679f82988016b7e5382629f'), ObjectId('6679f82988016b7e538262a0'), ObjectId('6679f82988016b7e538262a1'), ObjectId('6679f82988016b7e538262a2'), ObjectId('6679f82988016b7e538262a3'), ObjectId('6679f82988016b7e538262a4'), ObjectId('6679f82988016b7e538262a5'), ObjectId('6679f82988016b7e538262a6'), ObjectId('6679f82988016b7e538262a7'), ObjectId('6679f82988016b7e538262a8'), ObjectId('6679f82988016b7e538262a9'), ObjectId('6679f82988016b7e538262aa'), ObjectId('6679f82988016b7e538262ab'), ObjectId('6679f82988016b7e538262ac'), ObjectId('6679f82988016b7e538262ad'), ObjectId('6679f82988016b7e538262ae'), ObjectId('6679f82988016b7e538262af'), ObjectId('6679f82988016b7e538262b0')], acknowledged=True)

# %%
# query the shoeOrders collection
results = senate.find()

for senates in results:
    pprint(senates)
# Out:
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howell',
#  'Last_Name': 'Heflin',
#  'Party': 'D',
#  'State': 'Alabama',
#  'State Bird': 'Yellowhammer (northern flicker)',
#  '_id': ObjectId('6679f51088016b7e538261e4')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jeremiah',
#  'Last_Name': 'Denton',
#  'Party': 'R',
#  'State': 'Alabama',
#  'State Bird': 'Yellowhammer (northern flicker)',
#  '_id': ObjectId('6679f51088016b7e538261e5')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Ted',
#  'Last_Name': 'Stevens',
#  'Party': 'R',
#  'State': 'Alaska',
#  'State Bird': 'Willow ptarmigan',
#  '_id': ObjectId('6679f51088016b7e538261e6')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Frank',
#  'Last_Name': 'Murkowski',
#  'Party': 'R',
#  'State': 'Alaska',
#  'State Bird': 'Willow ptarmigan',
#  '_id': ObjectId('6679f51088016b7e538261e7')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dennis',
#  'Last_Name': 'DeConcini',
#  'Party': 'D',
#  'State': 'Arizona',
#  'State Bird': 'Cactus wren',
#  '_id': ObjectId('6679f51088016b7e538261e8')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Barry',
#  'Last_Name': 'Goldwater',
#  'Party': 'R',
#  'State': 'Arizona',
#  'State Bird': 'Cactus wren',
#  '_id': ObjectId('6679f51088016b7e538261e9')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Pryor',
#  'Party': 'D',
#  'State': 'Arkansas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e538261ea')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dale',
#  'Last_Name': 'Bumpers',
#  'Party': 'D',
#  'State': 'Arkansas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e538261eb')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'S.',
#  'Last_Name': 'Hayakawa',
#  'Party': 'R',
#  'State': 'California',
#  'State Bird': 'California quail',
#  '_id': ObjectId('6679f51088016b7e538261ec')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Cranston',
#  'Party': 'D',
#  'State': 'California',
#  'State Bird': 'California quail',
#  '_id': ObjectId('6679f51088016b7e538261ed')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Armstrong',
#  'Party': 'R',
#  'State': 'Colorado',
#  'State Bird': 'Lark bunting',
#  '_id': ObjectId('6679f51088016b7e538261ee')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Gary',
#  'Last_Name': 'Hart',
#  'Party': 'D',
#  'State': 'Colorado',
#  'State Bird': 'Lark bunting',
#  '_id': ObjectId('6679f51088016b7e538261ef')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lowell',
#  'Last_Name': 'Weicker',
#  'Party': 'R',
#  'State': 'Connecticut',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e538261f0')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Chris',
#  'Last_Name': 'Dodd',
#  'Party': 'D',
#  'State': 'Connecticut',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e538261f1')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Roth',
#  'Party': 'R',
#  'State': 'Delaware',
#  'State Bird': 'Delaware Blue Hen',
#  '_id': ObjectId('6679f51088016b7e538261f2')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Joe',
#  'Last_Name': 'Biden',
#  'Party': 'D',
#  'State': 'Delaware',
#  'State Bird': 'Delaware Blue Hen',
#  '_id': ObjectId('6679f51088016b7e538261f3')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lawton',
#  'Last_Name': 'Chiles',
#  'Party': 'D',
#  'State': 'Florida',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e538261f4')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paula',
#  'Last_Name': 'Hawkins',
#  'Party': 'R',
#  'State': 'Florida',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e538261f5')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Sam',
#  'Last_Name': 'Nunn',
#  'Party': 'D',
#  'State': 'Georgia',
#  'State Bird': 'Brown thrasher',
#  '_id': ObjectId('6679f51088016b7e538261f6')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mack',
#  'Last_Name': 'Mattingly',
#  'Party': 'R',
#  'State': 'Georgia',
#  'State Bird': 'Brown thrasher',
#  '_id': ObjectId('6679f51088016b7e538261f7')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Spark',
#  'Last_Name': 'Matsunaga',
#  'Party': 'D',
#  'State': 'Hawaii',
#  'State Bird': 'Hawaiian goose (nēnē)',
#  '_id': ObjectId('6679f51088016b7e538261f8')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Daniel',
#  'Last_Name': 'Inouye',
#  'Party': 'D',
#  'State': 'Hawaii',
#  'State Bird': 'Hawaiian goose (nēnē)',
#  '_id': ObjectId('6679f51088016b7e538261f9')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'James',
#  'Last_Name': 'McClure',
#  'Party': 'R',
#  'State': 'Idaho',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f51088016b7e538261fa')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Steve',
#  'Last_Name': 'Symms',
#  'Party': 'R',
#  'State': 'Idaho',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f51088016b7e538261fb')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Charles',
#  'Last_Name': 'Percy',
#  'Party': 'R',
#  'State': 'Illinois',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e538261fc')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Dixon',
#  'Party': 'D',
#  'State': 'Illinois',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e538261fd')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Richard',
#  'Last_Name': 'Lugar',
#  'Party': 'R',
#  'State': 'Indiana',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e538261fe')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dan',
#  'Last_Name': 'Quayle',
#  'Party': 'R',
#  'State': 'Indiana',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e538261ff')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Roger',
#  'Last_Name': 'Jepsen',
#  'Party': 'R',
#  'State': 'Iowa',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826200')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Chuck',
#  'Last_Name': 'Grassley',
#  'Party': 'R',
#  'State': 'Iowa',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826201')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Nancy',
#  'Last_Name': 'Kassebaum',
#  'Party': 'R',
#  'State': 'Kansas',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826202')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Dole',
#  'Party': 'R',
#  'State': 'Kansas',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826203')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Walter',
#  'Last_Name': 'Huddleston',
#  'Party': 'D',
#  'State': 'Kentucky',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826204')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Wendell',
#  'Last_Name': 'Ford',
#  'Party': 'D',
#  'State': 'Kentucky',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826205')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'J.',
#  'Last_Name': 'Johnston',
#  'Party': 'D',
#  'State': 'Louisiana',
#  'State Bird': 'Brown pelican',
#  '_id': ObjectId('6679f51088016b7e53826206')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Russell',
#  'Last_Name': 'Long',
#  'Party': 'D',
#  'State': 'Louisiana',
#  'State Bird': 'Brown pelican',
#  '_id': ObjectId('6679f51088016b7e53826207')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'George',
#  'Last_Name': 'Mitchell',
#  'Party': 'D',
#  'State': 'Maine',
#  'State Bird': 'Chickadee',
#  '_id': ObjectId('6679f51088016b7e53826208')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Cohen',
#  'Party': 'R',
#  'State': 'Maine',
#  'State Bird': 'Chickadee',
#  '_id': ObjectId('6679f51088016b7e53826209')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Sarbanes',
#  'Party': 'D',
#  'State': 'Maryland',
#  'State Bird': 'Baltimore oriole',
#  '_id': ObjectId('6679f51088016b7e5382620a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Charles',
#  'Last_Name': 'Mathias',
#  'Party': 'R',
#  'State': 'Maryland',
#  'State Bird': 'Baltimore oriole',
#  '_id': ObjectId('6679f51088016b7e5382620b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Ted',
#  'Last_Name': 'Kennedy',
#  'Party': 'D',
#  'State': 'Massachusetts',
#  'State Bird': 'Black-capped chickadee',
#  '_id': ObjectId('6679f51088016b7e5382620c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Tsongas',
#  'Party': 'D',
#  'State': 'Massachusetts',
#  'State Bird': 'Black-capped chickadee',
#  '_id': ObjectId('6679f51088016b7e5382620d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Donald',
#  'Last_Name': 'Riegle',
#  'Party': 'D',
#  'State': 'Michigan',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e5382620e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Carl',
#  'Last_Name': 'Levin',
#  'Party': 'D',
#  'State': 'Michigan',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e5382620f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Durenberger',
#  'Party': 'R',
#  'State': 'Minnesota',
#  'State Bird': 'Common loon',
#  '_id': ObjectId('6679f51088016b7e53826210')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Rudy',
#  'Last_Name': 'Boschwitz',
#  'Party': 'R',
#  'State': 'Minnesota',
#  'State Bird': 'Common loon',
#  '_id': ObjectId('6679f51088016b7e53826211')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Stennis',
#  'Party': 'D',
#  'State': 'Mississippi',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e53826212')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Thad',
#  'Last_Name': 'Cochran',
#  'Party': 'R',
#  'State': 'Mississippi',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e53826213')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Danforth',
#  'Party': 'R',
#  'State': 'Missouri',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f51088016b7e53826214')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Thomas',
#  'Last_Name': 'Eagleton',
#  'Party': 'D',
#  'State': 'Missouri',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f51088016b7e53826215')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Melcher',
#  'Party': 'D',
#  'State': 'Montana',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826216')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Max',
#  'Last_Name': 'Baucus',
#  'Party': 'D',
#  'State': 'Montana',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826217')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Edward',
#  'Last_Name': 'Zorinsky',
#  'Party': 'D',
#  'State': 'Nebraska',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826218')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'J.',
#  'Last_Name': 'Exon',
#  'Party': 'D',
#  'State': 'Nebraska',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826219')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Cannon',
#  'Party': 'D',
#  'State': 'Nevada',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f51088016b7e5382621a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Laxalt',
#  'Party': 'R',
#  'State': 'Nevada',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f51088016b7e5382621b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Gordon',
#  'Last_Name': 'Humphrey',
#  'Party': 'R',
#  'State': 'New Hampshire',
#  'State Bird': 'Purple finch',
#  '_id': ObjectId('6679f51088016b7e5382621c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Warren',
#  'Last_Name': 'Rudman',
#  'Party': 'R',
#  'State': 'New Hampshire',
#  'State Bird': 'Purple finch',
#  '_id': ObjectId('6679f51088016b7e5382621d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harrison',
#  'Last_Name': 'Williams',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e5382621e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Nicholas',
#  'Last_Name': 'Brady',
#  'Party': 'R',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e5382621f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Frank',
#  'Last_Name': 'Lautenberg',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826220')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bill',
#  'Last_Name': 'Bradley',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826221')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harrison',
#  'Last_Name': 'Schmitt',
#  'Party': 'R',
#  'State': 'New Mexico',
#  'State Bird': 'Greater roadrunner',
#  '_id': ObjectId('6679f51088016b7e53826222')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Pete',
#  'Last_Name': 'Domenici',
#  'Party': 'R',
#  'State': 'New Mexico',
#  'State Bird': 'Greater roadrunner',
#  '_id': ObjectId('6679f51088016b7e53826223')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Daniel',
#  'Last_Name': 'Moynihan',
#  'Party': 'D',
#  'State': 'New York',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f51088016b7e53826224')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Al',
#  'Last_Name': "D'Amato",
#  'Party': 'R',
#  'State': 'New York',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f51088016b7e53826225')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jesse',
#  'Last_Name': 'Helms',
#  'Party': 'R',
#  'State': 'North Carolina',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826226')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'East',
#  'Party': 'R',
#  'State': 'North Carolina',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826227')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Quentin',
#  'Last_Name': 'Burdick',
#  'Party': 'D-NPL',
#  'State': 'North Dakota',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826228')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mark',
#  'Last_Name': 'Andrews',
#  'Party': 'R',
#  'State': 'North Dakota',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826229')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Metzenbaum',
#  'Party': 'D',
#  'State': 'Ohio',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e5382622a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Glenn',
#  'Party': 'D',
#  'State': 'Ohio',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e5382622b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Boren',
#  'Party': 'D',
#  'State': 'Oklahoma',
#  'State Bird': 'Scissor-tailed flycatcher',
#  '_id': ObjectId('6679f51088016b7e5382622c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Don',
#  'Last_Name': 'Nickles',
#  'Party': 'R',
#  'State': 'Oklahoma',
#  'State Bird': 'Scissor-tailed flycatcher',
#  '_id': ObjectId('6679f51088016b7e5382622d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mark',
#  'Last_Name': 'Hatfield',
#  'Party': 'R',
#  'State': 'Oregon',
#  'State Bird': 'Western meadowlark(state songbird)[a]',
#  '_id': ObjectId('6679f51088016b7e5382622e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Packwood',
#  'Party': 'R',
#  'State': 'Oregon',
#  'State Bird': 'Western meadowlark(state songbird)[a]',
#  '_id': ObjectId('6679f51088016b7e5382622f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Heinz',
#  'Party': 'R',
#  'State': 'Pennsylvania',
#  'State Bird': 'Ruffed grouse[b]',
#  '_id': ObjectId('6679f51088016b7e53826230')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Arlen',
#  'Last_Name': 'Specter',
#  'Party': 'R',
#  'State': 'Pennsylvania',
#  'State Bird': 'Ruffed grouse[b]',
#  '_id': ObjectId('6679f51088016b7e53826231')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Chafee',
#  'Party': 'R',
#  'State': 'Rhode Island',
#  'State Bird': 'Rhode Island Red',
#  '_id': ObjectId('6679f51088016b7e53826232')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Claiborne',
#  'Last_Name': 'Pell',
#  'Party': 'D',
#  'State': 'Rhode Island',
#  'State Bird': 'Rhode Island Red',
#  '_id': ObjectId('6679f51088016b7e53826233')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Strom',
#  'Last_Name': 'Thurmond',
#  'Party': 'R',
#  'State': 'South Carolina',
#  'State Bird': 'Carolina wren',
#  '_id': ObjectId('6679f51088016b7e53826234')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Fritz',
#  'Last_Name': 'Hollings',
#  'Party': 'D',
#  'State': 'South Carolina',
#  'State Bird': 'Carolina wren',
#  '_id': ObjectId('6679f51088016b7e53826235')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Larry',
#  'Last_Name': 'Pressler',
#  'Party': 'R',
#  'State': 'South Dakota',
#  'State Bird': 'Ring-necked pheasant',
#  '_id': ObjectId('6679f51088016b7e53826236')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'James',
#  'Last_Name': 'Abdnor',
#  'Party': 'R',
#  'State': 'South Dakota',
#  'State Bird': 'Ring-necked pheasant',
#  '_id': ObjectId('6679f51088016b7e53826237')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jim',
#  'Last_Name': 'Sasser',
#  'Party': 'D',
#  'State': 'Tennessee',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e53826238')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Baker',
#  'Party': 'R',
#  'State': 'Tennessee',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e53826239')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lloyd',
#  'Last_Name': 'Bentsen',
#  'Party': 'D',
#  'State': 'Texas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e5382623a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Tower',
#  'Party': 'R',
#  'State': 'Texas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f51088016b7e5382623b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Orrin',
#  'Last_Name': 'Hatch',
#  'Party': 'R',
#  'State': 'Utah',
#  'State Bird': 'California gull',
#  '_id': ObjectId('6679f51088016b7e5382623c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jake',
#  'Last_Name': 'Garn',
#  'Party': 'R',
#  'State': 'Utah',
#  'State Bird': 'California gull',
#  '_id': ObjectId('6679f51088016b7e5382623d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Robert',
#  'Last_Name': 'Stafford',
#  'Party': 'R',
#  'State': 'Vermont',
#  'State Bird': 'Hermit thrush',
#  '_id': ObjectId('6679f51088016b7e5382623e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Patrick',
#  'Last_Name': 'Leahy',
#  'Party': 'D',
#  'State': 'Vermont',
#  'State Bird': 'Hermit thrush',
#  '_id': ObjectId('6679f51088016b7e5382623f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harry',
#  'Last_Name': 'Byrd',
#  'Party': 'I',
#  'State': 'Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826240')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Warner',
#  'Party': 'R',
#  'State': 'Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826241')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Henry',
#  'Last_Name': 'Jackson',
#  'Party': 'D',
#  'State': 'Washington',
#  'State Bird': 'Willow goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826242')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Slade',
#  'Last_Name': 'Gorton',
#  'Party': 'R',
#  'State': 'Washington',
#  'State Bird': 'Willow goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f51088016b7e53826243')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Robert',
#  'Last_Name': 'Byrd',
#  'Party': 'D',
#  'State': 'West Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826244')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jennings',
#  'Last_Name': 'Randolph',
#  'Party': 'D',
#  'State': 'West Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f51088016b7e53826245')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Proxmire',
#  'Party': 'D',
#  'State': 'Wisconsin',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e53826246')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Kasten',
#  'Party': 'R',
#  'State': 'Wisconsin',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f51088016b7e53826247')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Malcolm',
#  'Last_Name': 'Wallop',
#  'Party': 'R',
#  'State': 'Wyoming',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826248')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Simpson',
#  'Party': 'R',
#  'State': 'Wyoming',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f51088016b7e53826249')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howell',
#  'Last_Name': 'Heflin',
#  'Party': 'D',
#  'State': 'Alabama',
#  'State Bird': 'Yellowhammer (northern flicker)',
#  '_id': ObjectId('6679f82988016b7e5382624b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jeremiah',
#  'Last_Name': 'Denton',
#  'Party': 'R',
#  'State': 'Alabama',
#  'State Bird': 'Yellowhammer (northern flicker)',
#  '_id': ObjectId('6679f82988016b7e5382624c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Ted',
#  'Last_Name': 'Stevens',
#  'Party': 'R',
#  'State': 'Alaska',
#  'State Bird': 'Willow ptarmigan',
#  '_id': ObjectId('6679f82988016b7e5382624d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Frank',
#  'Last_Name': 'Murkowski',
#  'Party': 'R',
#  'State': 'Alaska',
#  'State Bird': 'Willow ptarmigan',
#  '_id': ObjectId('6679f82988016b7e5382624e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dennis',
#  'Last_Name': 'DeConcini',
#  'Party': 'D',
#  'State': 'Arizona',
#  'State Bird': 'Cactus wren',
#  '_id': ObjectId('6679f82988016b7e5382624f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Barry',
#  'Last_Name': 'Goldwater',
#  'Party': 'R',
#  'State': 'Arizona',
#  'State Bird': 'Cactus wren',
#  '_id': ObjectId('6679f82988016b7e53826250')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Pryor',
#  'Party': 'D',
#  'State': 'Arkansas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e53826251')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dale',
#  'Last_Name': 'Bumpers',
#  'Party': 'D',
#  'State': 'Arkansas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e53826252')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'S.',
#  'Last_Name': 'Hayakawa',
#  'Party': 'R',
#  'State': 'California',
#  'State Bird': 'California quail',
#  '_id': ObjectId('6679f82988016b7e53826253')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Cranston',
#  'Party': 'D',
#  'State': 'California',
#  'State Bird': 'California quail',
#  '_id': ObjectId('6679f82988016b7e53826254')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Armstrong',
#  'Party': 'R',
#  'State': 'Colorado',
#  'State Bird': 'Lark bunting',
#  '_id': ObjectId('6679f82988016b7e53826255')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Gary',
#  'Last_Name': 'Hart',
#  'Party': 'D',
#  'State': 'Colorado',
#  'State Bird': 'Lark bunting',
#  '_id': ObjectId('6679f82988016b7e53826256')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lowell',
#  'Last_Name': 'Weicker',
#  'Party': 'R',
#  'State': 'Connecticut',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e53826257')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Chris',
#  'Last_Name': 'Dodd',
#  'Party': 'D',
#  'State': 'Connecticut',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e53826258')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Roth',
#  'Party': 'R',
#  'State': 'Delaware',
#  'State Bird': 'Delaware Blue Hen',
#  '_id': ObjectId('6679f82988016b7e53826259')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Joe',
#  'Last_Name': 'Biden',
#  'Party': 'D',
#  'State': 'Delaware',
#  'State Bird': 'Delaware Blue Hen',
#  '_id': ObjectId('6679f82988016b7e5382625a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lawton',
#  'Last_Name': 'Chiles',
#  'Party': 'D',
#  'State': 'Florida',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e5382625b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paula',
#  'Last_Name': 'Hawkins',
#  'Party': 'R',
#  'State': 'Florida',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e5382625c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Sam',
#  'Last_Name': 'Nunn',
#  'Party': 'D',
#  'State': 'Georgia',
#  'State Bird': 'Brown thrasher',
#  '_id': ObjectId('6679f82988016b7e5382625d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mack',
#  'Last_Name': 'Mattingly',
#  'Party': 'R',
#  'State': 'Georgia',
#  'State Bird': 'Brown thrasher',
#  '_id': ObjectId('6679f82988016b7e5382625e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Spark',
#  'Last_Name': 'Matsunaga',
#  'Party': 'D',
#  'State': 'Hawaii',
#  'State Bird': 'Hawaiian goose (nēnē)',
#  '_id': ObjectId('6679f82988016b7e5382625f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Daniel',
#  'Last_Name': 'Inouye',
#  'Party': 'D',
#  'State': 'Hawaii',
#  'State Bird': 'Hawaiian goose (nēnē)',
#  '_id': ObjectId('6679f82988016b7e53826260')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'James',
#  'Last_Name': 'McClure',
#  'Party': 'R',
#  'State': 'Idaho',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f82988016b7e53826261')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Steve',
#  'Last_Name': 'Symms',
#  'Party': 'R',
#  'State': 'Idaho',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f82988016b7e53826262')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Charles',
#  'Last_Name': 'Percy',
#  'Party': 'R',
#  'State': 'Illinois',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826263')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Dixon',
#  'Party': 'D',
#  'State': 'Illinois',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826264')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Richard',
#  'Last_Name': 'Lugar',
#  'Party': 'R',
#  'State': 'Indiana',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826265')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Dan',
#  'Last_Name': 'Quayle',
#  'Party': 'R',
#  'State': 'Indiana',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826266')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Roger',
#  'Last_Name': 'Jepsen',
#  'Party': 'R',
#  'State': 'Iowa',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826267')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Chuck',
#  'Last_Name': 'Grassley',
#  'Party': 'R',
#  'State': 'Iowa',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826268')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Nancy',
#  'Last_Name': 'Kassebaum',
#  'Party': 'R',
#  'State': 'Kansas',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e53826269')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Dole',
#  'Party': 'R',
#  'State': 'Kansas',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e5382626a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Walter',
#  'Last_Name': 'Huddleston',
#  'Party': 'D',
#  'State': 'Kentucky',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e5382626b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Wendell',
#  'Last_Name': 'Ford',
#  'Party': 'D',
#  'State': 'Kentucky',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e5382626c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'J.',
#  'Last_Name': 'Johnston',
#  'Party': 'D',
#  'State': 'Louisiana',
#  'State Bird': 'Brown pelican',
#  '_id': ObjectId('6679f82988016b7e5382626d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Russell',
#  'Last_Name': 'Long',
#  'Party': 'D',
#  'State': 'Louisiana',
#  'State Bird': 'Brown pelican',
#  '_id': ObjectId('6679f82988016b7e5382626e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'George',
#  'Last_Name': 'Mitchell',
#  'Party': 'D',
#  'State': 'Maine',
#  'State Bird': 'Chickadee',
#  '_id': ObjectId('6679f82988016b7e5382626f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Cohen',
#  'Party': 'R',
#  'State': 'Maine',
#  'State Bird': 'Chickadee',
#  '_id': ObjectId('6679f82988016b7e53826270')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Sarbanes',
#  'Party': 'D',
#  'State': 'Maryland',
#  'State Bird': 'Baltimore oriole',
#  '_id': ObjectId('6679f82988016b7e53826271')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Charles',
#  'Last_Name': 'Mathias',
#  'Party': 'R',
#  'State': 'Maryland',
#  'State Bird': 'Baltimore oriole',
#  '_id': ObjectId('6679f82988016b7e53826272')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Ted',
#  'Last_Name': 'Kennedy',
#  'Party': 'D',
#  'State': 'Massachusetts',
#  'State Bird': 'Black-capped chickadee',
#  '_id': ObjectId('6679f82988016b7e53826273')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Tsongas',
#  'Party': 'D',
#  'State': 'Massachusetts',
#  'State Bird': 'Black-capped chickadee',
#  '_id': ObjectId('6679f82988016b7e53826274')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Donald',
#  'Last_Name': 'Riegle',
#  'Party': 'D',
#  'State': 'Michigan',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e53826275')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Carl',
#  'Last_Name': 'Levin',
#  'Party': 'D',
#  'State': 'Michigan',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e53826276')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Durenberger',
#  'Party': 'R',
#  'State': 'Minnesota',
#  'State Bird': 'Common loon',
#  '_id': ObjectId('6679f82988016b7e53826277')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Rudy',
#  'Last_Name': 'Boschwitz',
#  'Party': 'R',
#  'State': 'Minnesota',
#  'State Bird': 'Common loon',
#  '_id': ObjectId('6679f82988016b7e53826278')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Stennis',
#  'Party': 'D',
#  'State': 'Mississippi',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e53826279')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Thad',
#  'Last_Name': 'Cochran',
#  'Party': 'R',
#  'State': 'Mississippi',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e5382627a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Danforth',
#  'Party': 'R',
#  'State': 'Missouri',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f82988016b7e5382627b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Thomas',
#  'Last_Name': 'Eagleton',
#  'Party': 'D',
#  'State': 'Missouri',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f82988016b7e5382627c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Melcher',
#  'Party': 'D',
#  'State': 'Montana',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e5382627d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Max',
#  'Last_Name': 'Baucus',
#  'Party': 'D',
#  'State': 'Montana',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e5382627e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Edward',
#  'Last_Name': 'Zorinsky',
#  'Party': 'D',
#  'State': 'Nebraska',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e5382627f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'J.',
#  'Last_Name': 'Exon',
#  'Party': 'D',
#  'State': 'Nebraska',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e53826280')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Cannon',
#  'Party': 'D',
#  'State': 'Nevada',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f82988016b7e53826281')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Paul',
#  'Last_Name': 'Laxalt',
#  'Party': 'R',
#  'State': 'Nevada',
#  'State Bird': 'Mountain bluebird',
#  '_id': ObjectId('6679f82988016b7e53826282')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Gordon',
#  'Last_Name': 'Humphrey',
#  'Party': 'R',
#  'State': 'New Hampshire',
#  'State Bird': 'Purple finch',
#  '_id': ObjectId('6679f82988016b7e53826283')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Warren',
#  'Last_Name': 'Rudman',
#  'Party': 'R',
#  'State': 'New Hampshire',
#  'State Bird': 'Purple finch',
#  '_id': ObjectId('6679f82988016b7e53826284')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harrison',
#  'Last_Name': 'Williams',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826285')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Nicholas',
#  'Last_Name': 'Brady',
#  'Party': 'R',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826286')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Frank',
#  'Last_Name': 'Lautenberg',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826287')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bill',
#  'Last_Name': 'Bradley',
#  'Party': 'D',
#  'State': 'New Jersey',
#  'State Bird': 'Eastern goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e53826288')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harrison',
#  'Last_Name': 'Schmitt',
#  'Party': 'R',
#  'State': 'New Mexico',
#  'State Bird': 'Greater roadrunner',
#  '_id': ObjectId('6679f82988016b7e53826289')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Pete',
#  'Last_Name': 'Domenici',
#  'Party': 'R',
#  'State': 'New Mexico',
#  'State Bird': 'Greater roadrunner',
#  '_id': ObjectId('6679f82988016b7e5382628a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Daniel',
#  'Last_Name': 'Moynihan',
#  'Party': 'D',
#  'State': 'New York',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f82988016b7e5382628b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Al',
#  'Last_Name': "D'Amato",
#  'Party': 'R',
#  'State': 'New York',
#  'State Bird': 'Eastern bluebird',
#  '_id': ObjectId('6679f82988016b7e5382628c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jesse',
#  'Last_Name': 'Helms',
#  'Party': 'R',
#  'State': 'North Carolina',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e5382628d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'East',
#  'Party': 'R',
#  'State': 'North Carolina',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e5382628e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Quentin',
#  'Last_Name': 'Burdick',
#  'Party': 'D-NPL',
#  'State': 'North Dakota',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e5382628f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mark',
#  'Last_Name': 'Andrews',
#  'Party': 'R',
#  'State': 'North Dakota',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e53826290')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Metzenbaum',
#  'Party': 'D',
#  'State': 'Ohio',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826291')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Glenn',
#  'Party': 'D',
#  'State': 'Ohio',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e53826292')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'David',
#  'Last_Name': 'Boren',
#  'Party': 'D',
#  'State': 'Oklahoma',
#  'State Bird': 'Scissor-tailed flycatcher',
#  '_id': ObjectId('6679f82988016b7e53826293')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Don',
#  'Last_Name': 'Nickles',
#  'Party': 'R',
#  'State': 'Oklahoma',
#  'State Bird': 'Scissor-tailed flycatcher',
#  '_id': ObjectId('6679f82988016b7e53826294')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Mark',
#  'Last_Name': 'Hatfield',
#  'Party': 'R',
#  'State': 'Oregon',
#  'State Bird': 'Western meadowlark(state songbird)[a]',
#  '_id': ObjectId('6679f82988016b7e53826295')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Packwood',
#  'Party': 'R',
#  'State': 'Oregon',
#  'State Bird': 'Western meadowlark(state songbird)[a]',
#  '_id': ObjectId('6679f82988016b7e53826296')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Heinz',
#  'Party': 'R',
#  'State': 'Pennsylvania',
#  'State Bird': 'Ruffed grouse[b]',
#  '_id': ObjectId('6679f82988016b7e53826297')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Arlen',
#  'Last_Name': 'Specter',
#  'Party': 'R',
#  'State': 'Pennsylvania',
#  'State Bird': 'Ruffed grouse[b]',
#  '_id': ObjectId('6679f82988016b7e53826298')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Chafee',
#  'Party': 'R',
#  'State': 'Rhode Island',
#  'State Bird': 'Rhode Island Red',
#  '_id': ObjectId('6679f82988016b7e53826299')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Claiborne',
#  'Last_Name': 'Pell',
#  'Party': 'D',
#  'State': 'Rhode Island',
#  'State Bird': 'Rhode Island Red',
#  '_id': ObjectId('6679f82988016b7e5382629a')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Strom',
#  'Last_Name': 'Thurmond',
#  'Party': 'R',
#  'State': 'South Carolina',
#  'State Bird': 'Carolina wren',
#  '_id': ObjectId('6679f82988016b7e5382629b')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Fritz',
#  'Last_Name': 'Hollings',
#  'Party': 'D',
#  'State': 'South Carolina',
#  'State Bird': 'Carolina wren',
#  '_id': ObjectId('6679f82988016b7e5382629c')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Larry',
#  'Last_Name': 'Pressler',
#  'Party': 'R',
#  'State': 'South Dakota',
#  'State Bird': 'Ring-necked pheasant',
#  '_id': ObjectId('6679f82988016b7e5382629d')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'James',
#  'Last_Name': 'Abdnor',
#  'Party': 'R',
#  'State': 'South Dakota',
#  'State Bird': 'Ring-necked pheasant',
#  '_id': ObjectId('6679f82988016b7e5382629e')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jim',
#  'Last_Name': 'Sasser',
#  'Party': 'D',
#  'State': 'Tennessee',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e5382629f')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Howard',
#  'Last_Name': 'Baker',
#  'Party': 'R',
#  'State': 'Tennessee',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e538262a0')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Lloyd',
#  'Last_Name': 'Bentsen',
#  'Party': 'D',
#  'State': 'Texas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e538262a1')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Tower',
#  'Party': 'R',
#  'State': 'Texas',
#  'State Bird': 'Northern mockingbird',
#  '_id': ObjectId('6679f82988016b7e538262a2')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Orrin',
#  'Last_Name': 'Hatch',
#  'Party': 'R',
#  'State': 'Utah',
#  'State Bird': 'California gull',
#  '_id': ObjectId('6679f82988016b7e538262a3')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jake',
#  'Last_Name': 'Garn',
#  'Party': 'R',
#  'State': 'Utah',
#  'State Bird': 'California gull',
#  '_id': ObjectId('6679f82988016b7e538262a4')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Robert',
#  'Last_Name': 'Stafford',
#  'Party': 'R',
#  'State': 'Vermont',
#  'State Bird': 'Hermit thrush',
#  '_id': ObjectId('6679f82988016b7e538262a5')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Patrick',
#  'Last_Name': 'Leahy',
#  'Party': 'D',
#  'State': 'Vermont',
#  'State Bird': 'Hermit thrush',
#  '_id': ObjectId('6679f82988016b7e538262a6')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Harry',
#  'Last_Name': 'Byrd',
#  'Party': 'I',
#  'State': 'Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e538262a7')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'John',
#  'Last_Name': 'Warner',
#  'Party': 'R',
#  'State': 'Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e538262a8')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Henry',
#  'Last_Name': 'Jackson',
#  'Party': 'D',
#  'State': 'Washington',
#  'State Bird': 'Willow goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e538262a9')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Slade',
#  'Last_Name': 'Gorton',
#  'Party': 'R',
#  'State': 'Washington',
#  'State Bird': 'Willow goldfinch (American goldfinch)',
#  '_id': ObjectId('6679f82988016b7e538262aa')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Robert',
#  'Last_Name': 'Byrd',
#  'Party': 'D',
#  'State': 'West Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e538262ab')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Jennings',
#  'Last_Name': 'Randolph',
#  'Party': 'D',
#  'State': 'West Virginia',
#  'State Bird': 'Northern cardinal',
#  '_id': ObjectId('6679f82988016b7e538262ac')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'William',
#  'Last_Name': 'Proxmire',
#  'Party': 'D',
#  'State': 'Wisconsin',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e538262ad')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Bob',
#  'Last_Name': 'Kasten',
#  'Party': 'R',
#  'State': 'Wisconsin',
#  'State Bird': 'American robin',
#  '_id': ObjectId('6679f82988016b7e538262ae')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Malcolm',
#  'Last_Name': 'Wallop',
#  'Party': 'R',
#  'State': 'Wyoming',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e538262af')}
# {'Chamber': 'Senate',
#  'Congressional_Year': 1981,
#  'First_Name': 'Alan',
#  'Last_Name': 'Simpson',
#  'Party': 'R',
#  'State': 'Wyoming',
#  'State Bird': 'Western meadowlark',
#  '_id': ObjectId('6679f82988016b7e538262b0')}
